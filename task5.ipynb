# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("C:/Users/khasi/OneDrive/Desktop/elevate labs/student_habits_performance.csv")
df
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# ..        ...  ...     ...                  ...                 ...
# 93      S1093   22    Male                  4.1                 2.5
# 94      S1094   22  Female                  5.3                 1.0
# 95      S1095   22    Male                  1.7                 2.9
# 96      S1096   18  Female                  6.0                 3.6
# 97      S1097   20    Male                  4.1                 2.0
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0             1.1            No                   85.0          8.0
# ...

# %%
# Consider only the first 98 entries
df = df.head(98)
df
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# ..        ...  ...     ...                  ...                 ...
# 93      S1093   22    Male                  4.1                 2.5
# 94      S1094   22  Female                  5.3                 1.0
# 95      S1095   22    Male                  1.7                 2.9
# 96      S1096   18  Female                  6.0                 3.6
# 97      S1097   20    Male                  4.1                 2.0
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0             1.1            No                   85.0          8.0
# ...

# %%
# Basic Info
print("Data Info:")
print(df.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     98 non-null     object
#  1   age                            98 non-null     int64
#  2   gender                         98 non-null     object
#  3   study_hours_per_day            98 non-null     float64
#  4   social_media_hours             98 non-null     float64
#  5   netflix_hours                  98 non-null     float64
#  6   part_time_job                  98 non-null     object
#  7   attendance_percentage          98 non-null     float64
#  8   sleep_hours                    98 non-null     float64
#  9   diet_quality                   98 non-null     object
#  10  exercise_frequency             98 non-null     int64
#  11  parental_education_level       93 non-null     object
# ...

# %%
# Summary Statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  98.000000            98.000000           98.000000      98.000000
# mean   20.581633             3.522449            2.524490       1.825510
# std     2.163061             1.595841            1.212483       1.133402
# min    17.000000             0.000000            0.000000       0.000000
# 25%    19.000000             2.400000            1.700000       0.925000
# 50%    20.000000             3.600000            2.450000       2.000000
# 75%    22.000000             4.400000            3.375000       2.600000
# max    24.000000             7.400000            5.000000       5.000000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count              98.000000    98.000000           98.000000
# mean               85.036735     6.622449            3.112245
# std                 9.699659     1.243998            2.114665
# ...

# %%
# Value Counts for categorical columns
for col in df.select_dtypes(include='object').columns:
    print(f"\nValue counts for {col}:\n", df[col].value_counts())
# Out:
# Value counts for student_id:
#  student_id
# S1000    1
# S1073    1
# S1071    1
# S1070    1
# S1069    1
#         ..
# S1030    1
# S1029    1
# S1028    1
# S1027    1
# S1097    1
# Name: count, Length: 98, dtype: int64
#
# Value counts for gender:
#  gender
# Female    50
# Male      43
# Other      5
# Name: count, dtype: int64
#
# Value counts for part_time_job:
#  part_time_job
# No     76
# Yes    22
# Name: count, dtype: int64
#
# Value counts for diet_quality:
#  diet_quality
# Fair    40
# Good    36
# Poor    22
# Name: count, dtype: int64
#
# Value counts for parental_education_level:
#  parental_education_level
# High School    40
# Bachelor       37
# Master         16
# Name: count, dtype: int64
#
# Value counts for internet_quality:
#  internet_quality
# Average    43
# Good       40
# Poor       15
# Name: count, dtype: int64
#
# Value counts for extracurricular_participation:
#  extracurricular_participation
# No     70
# Yes    28
# Name: count, dtype: int64

# %%
# Pairplot
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\khasi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\khasi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\khasi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Correlation Heatmap (only numeric columns)
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histograms
df.hist(figsize=(12, 10), bins=20)
plt.suptitle('Histograms of Features')
plt.show()

# %%
# Boxplots
plt.figure(figsize=(12,8))
sns.boxplot(data=df)
plt.title('Boxplots of Numeric Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatterplot Example
plt.figure(figsize=(6,4))
sns.scatterplot(x='study_hours_per_day', y='exam_score', data=df)
plt.title('Study Hours vs Performance Score')
plt.show()
